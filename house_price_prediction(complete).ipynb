# %%
#read the csv file using pandas
import pandas as pd
data = pd.read_csv("http://hackveda.in/sistec/Housing_Modified.csv")
data
# Out:
#         price  lotsize  bedrooms  bathrms  ... gashw airco garagepl prefarea
# 0     42000.0     5850         3        1  ...    no    no        1       no
# 1     38500.0     4000         2        1  ...    no    no        0       no
# 2     49500.0     3060         3        1  ...    no    no        0       no
# 3     60500.0     6650         3        1  ...    no    no        0       no
# 4     61000.0     6360         2        1  ...    no    no        0       no
# 5     66000.0     4160         3        1  ...    no   yes        0       no
# 6     66000.0     3880         3        2  ...    no    no        2       no
# 7     69000.0     4160         3        1  ...    no    no        0       no
# 8     83800.0     4800         3        1  ...    no    no        0       no
# 9     88500.0     5500         3        2  ...    no   yes        1       no
# 10    90000.0     7200         3        2  ...    no   yes        3       no
# ...

# %%
#type of data variable 
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Dataframe operations 
# show values from top
# ?data.head()
data.head(3)
data.tail(2)
#extract coustom values from dataframe
#extract index/row wise
data['price'][50]
# Out:
# 55000.0

# %%
# Extract knowledge from the dataset using KDD(Knowledge discovery proces)
#KDD process has the following stages 
"""
KDD stages 
1. data selection
2. data pre processing
3. data transformation
4. model interpratation and evaluation
Knowledge is extracted
"""
# Out:
# '\nKDD stages \n1. data selection\n2. data pre processing\n3. data transformation\n4. model interpratation and evaluation\nKnowledge is extracted\n'

# %%
#STAGE 1= data selection process

#show the rows and columns in data
print("Rows vs Columns in data",data.shape)
print("rows %d and columns %d" % data.shape)
#calculate covariance among features/factors/variables

data.cov()
#calculate correlation among factors/features/variables
# Out:
# Rows vs Columns in data (546, 12)
# rows 546 and columns 12
#                  price       lotsize     bedrooms      bathrms     garagepl
# price     7.130326e+08  3.102023e+07  7215.431824  6928.665793  8815.633592
# lotsize   3.102023e+07  4.700912e+06   242.776231   211.037746   658.969936
# bedrooms  7.215432e+03  2.427762e+02     0.543741     0.138401     0.088356
# bathrms   6.928666e+03  2.110377e+02     0.138401     0.252163     0.077064
# garagepl  8.815634e+03  6.589699e+02     0.088356     0.077064     0.741849

# %%
#calculate positive and negative relation 
#in percentage( correlation )
data.corr()
# Out:
#              price   lotsize  bedrooms   bathrms  garagepl
# price     1.000000  0.535796  0.366447  0.516719  0.383302
# lotsize   0.535796  1.000000  0.151851  0.193833  0.352872
# bedrooms  0.366447  0.151851  1.000000  0.373769  0.139117
# bathrms   0.516719  0.193833  0.373769  1.000000  0.178178
# garagepl  0.383302  0.352872  0.139117  0.178178  1.000000

# %%
#STAGE 2 = Pre-processing
"""
case 1: Binary category 
(yes/no),(true/false),(one/two)
technique = Label Binarizer
Binarize the variable from text to number
one and two= 1 & 2 or 0 and 1
"""

"""
case 2: N-category 
technique =label encoding
one-hot encoding/ one cold encoding
"""
# Out:
# '\ncase 2: N-category \ntechnique =label encoding\none-hot encoding/ one cold encoding\n'

# %%
# STAGE 2 = pre processing
#Import pre processing library from sklearn
#Label binarizer

import sklearn.preprocessing as pp
lb = pp.LabelBinarizer()
data.driveway = lb.fit_transform(data.driveway)
data.recroom = lb.fit_transform(data.recroom)
data.fullbase = lb.fit_transform(data.fullbase)
data.gashw = lb.fit_transform(data.gashw)
data.airco = lb.fit_transform(data.airco)
data.prefarea = lb.fit_transform(data.prefarea)
data.head(2)

#data.corr()
# Out:
#      price  lotsize  bedrooms  bathrms  ... gashw  airco  garagepl  prefarea
# 0  42000.0     5850         3        1  ...     0      0         1         0
# 1  38500.0     4000         2        1  ...     0      0         0         0
#
# [2 rows x 12 columns]

# %%
#one hot encoding

data_stories = pd.get_dummies(data['stories'],prefix ='stories')
data = pd.concat([data,data_stories],axis = 1)# axis 1 = column wise
del data['stories']
data.head(3)
# Out:
#      price  lotsize  bedrooms  ...  stories_one  stories_three  stories_two
# 0  42000.0     5850         3  ...            0              0            1
# 1  38500.0     4000         2  ...            1              0            0
# 2  49500.0     3060         3  ...            1              0            0
#
# [3 rows x 15 columns]

# %%
#to generate summary of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 15 columns):
# price            546 non-null float64
# lotsize          546 non-null int64
# bedrooms         546 non-null int64
# bathrms          546 non-null int64
# driveway         546 non-null int64
# recroom          546 non-null int64
# fullbase         546 non-null int64
# gashw            546 non-null int64
# airco            546 non-null int64
# garagepl         546 non-null int64
# prefarea         546 non-null int64
# stories_four     546 non-null uint8
# stories_one      546 non-null uint8
# stories_three    546 non-null uint8
# stories_two      546 non-null uint8
# dtypes: float64(1), int64(10), uint8(4)
# memory usage: 49.1 KB

# %%
data.corr()
# Out:
#                   price   lotsize  ...  stories_three  stories_two
# price          1.000000  0.535796  ...       0.138254    -0.002089
# lotsize        0.535796  1.000000  ...       0.020567    -0.159612
# bedrooms       0.366447  0.151851  ...       0.099150     0.377424
# bathrms        0.516719  0.193833  ...       0.036027     0.080982
# driveway       0.297167  0.288778  ...       0.073533    -0.047074
# recroom        0.254960  0.140327  ...      -0.038733     0.006938
# fullbase       0.186218  0.047487  ...      -0.132540     0.098694
# gashw          0.092837 -0.009201  ...       0.072922     0.054823
# airco          0.453347  0.221765  ...       0.110682    -0.074706
# garagepl       0.383302  0.352872  ...      -0.079170    -0.041931
# prefarea       0.329074  0.234782  ...       0.143067    -0.059240
# stories_four   0.372281  0.178354  ...      -0.080113    -0.250472
# stories_one   -0.270058  0.054348  ...      -0.237177    -0.741533
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

sns.heatmap(data.corr(),square=True,annot=True,fmt='.1f')

# %%
# VIF
data.columns
# Out:
# Index(['price', 'lotsize', 'bedrooms', 'bathrms', 'driveway', 'recroom',
#        'fullbase', 'gashw', 'airco', 'garagepl', 'prefarea', 'stories_four',
#        'stories_one', 'stories_three', 'stories_two'],
#       dtype='object')

# %%
#create a seperate list of independent_variables

independent_variables = ['lotsize','bedrooms','bathrms','driveway',
                         'recroom','fullbase',
                         'gashw','airco',
                        'garagepl','prefarea',
                        'stories_four','stories_one',
                        'stories_three','stories_two']
independent_variables
# Out:
# ['lotsize',
#  'bedrooms',
#  'bathrms',
#  'driveway',
#  'recroom',
#  'fullbase',
#  'gashw',
#  'airco',
#  'garagepl',
#  'prefarea',
#  'stories_four',
#  'stories_one',
#  'stories_three',
#  'stories_two']

# %%
# compute MultiCollinearity
# VIF--> variance inflation factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

# %%
x = data[independent_variables]
y = data['price']
y

# VIF value greater than 10 means they are correlated 

thresh = 10 # it is an indicator for VIF

for i in np.arange(0,len(independent_variables)):
  vif = [variance_inflation_factor(x[independent_variables].values,ix)
  for ix in range(x[independent_variables].shape[1])]
 #nested list comprehension 
  maxloc = vif.index(max(vif)) 
  
  if max(vif) > thresh:
    print("VIF:",vif)
    print("Dropping:",x[independent_variables].columns[maxloc],
         "at index",maxloc)
    del independent_variables[maxloc]
    
  else:
      break
      
print('\n final independent variables:\n',independent_variables)
# Out:
# VIF: [1.3704738112004569, 1.578326825971881, 1.2987779728705593, 1.1648811574651847, 1.2148620093192928, 1.3369114662383517, 1.053078869775805, 1.2195823546735252, 1.218832929061305, 1.181239434106175, 4.544836339845972, 11.781465345739338, 3.943698568447546, 17.220894903652624]
# Dropping: stories_two at index 13
# VIF: [9.027672411240845, 12.40877864989557, 9.374682124313615, 6.79426994395169, 1.4753724454932144, 2.055797712632684, 1.103128332756141, 1.785054332017555, 1.9607784997238857, 1.5317205065647905, 1.4546157757803124, 1.8969940907498246, 1.278600527923588]
# Dropping: bedrooms at index 1
#
#  final independent variables:
#  ['lotsize', 'bathrms', 'driveway', 'recroom', 'fullbase', 'gashw', 'airco', 'garagepl', 'prefarea', 'stories_four', 'stories_one', 'stories_three']

# %%
independent_variables=['lotsize', 'bathrms', 'driveway',
                       'recroom', 'fullbase', 'gashw', 
                       'airco', 'garagepl', 'prefarea',
                       'stories_four', 'stories_one', 'stories_three']

# %%
x = data[independent_variables]
y = data['price']
print(x.shape)
print(y.shape)
# split our dataset into training/testing set

# 100 rows--> 80rows(training)  20 rows(testing)

#80 rows(training)--> linear regression (predicted values)

#20 rows(testing) 4200 2000 ---> 50% accuracy
# Out:
# (546, 12)
# (546,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=.80,random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (436, 12)
# (110, 12)
# (436,)
# (110,)

# %%
x.values
# Out:
# array([[5850,    1,    1, ...,    0,    0,    0],
#        [4000,    1,    1, ...,    0,    1,    0],
#        [3060,    1,    1, ...,    0,    1,    0],
#        ...,
#        [6000,    2,    1, ...,    1,    0,    0],
#        [6000,    2,    1, ...,    0,    0,    0],
#        [6000,    1,    1, ...,    0,    0,    0]])

# %%
# OLS models
#!pip install -U statsmodels
'''!pip install --upgrade Cython
# !pip install --upgrade git+https://github.com/statsmodels/statsmodels'''
import statsmodels.api as sm

# %%
lm = sm.OLS(y_train,x_train).fit()
print(lm.summary())
#0.05 above value of pt it has multicolinearity
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.956
# Model:                            OLS   Adj. R-squared (uncentered):              0.954
# Method:                 Least Squares   F-statistic:                              760.6
# Date:                Tue, 25 Jun 2019   Prob (F-statistic):                   5.22e-278
# Time:                        06:27:19   Log-Likelihood:                         -4819.9
# No. Observations:                 436   AIC:                                      9664.
# Df Residuals:                     424   BIC:                                      9713.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
independent_variables=['lotsize', 'bathrms', 'driveway',
                        'fullbase', 'gashw', 
                       'airco', 'garagepl', 'prefarea',
                       'stories_four', 'stories_one', 'stories_three']
x = data[independent_variables]
y = data['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=.80,random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (436, 11)
# (110, 11)
# (436,)
# (110,)

# %%
lm = sm.OLS(y_train,x_train).fit()
print(lm.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.954
# Method:                 Least Squares   F-statistic:                              828.0
# Date:                Tue, 25 Jun 2019   Prob (F-statistic):                   4.34e-279
# Time:                        06:27:19   Log-Likelihood:                         -4820.8
# No. Observations:                 436   AIC:                                      9664.
# Df Residuals:                     425   BIC:                                      9708.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# now take info of 11 col from user 
lotsize = int(input('Enter Lot size:'))
bathrms = int(input('Enter Bathrooms:'))
driveway = int(input('Enter Drive way:'))
fullbase = int(input('Enter Fullbase:'))
gashw = int(input('Enter gas hot water:'))
airco = int(input('Enter Air condition:'))
garagepl = int(input('Enter garage place:'))
prefarea = int(input('Enter prefarea:'))
stories_four = int(input('Enter story four:'))
stories_one = int(input('Enter story one:'))
stories_three = int(input('Enter story three:'))

#convert these input into dictionaries

dict1 = {'lotsize':lotsize, 'bathrms':bathrms, 'driveway':driveway, 'fullbase':fullbase,
        'gashw':gashw,'airco':airco,'garagepl':garagepl,'prefarea':prefarea,
        'stories_four':stories_four, 'stories_one':stories_one,
         'stories_three':stories_three}

#convert dictionary into dataframe

data_input = pd.DataFrame(dict1,index=[0],columns=['lotsize','bathrms','driveway',
                                                 'fullbase','gashw','airco','garagepl',
                                                  'prefarea','stories_four','stories_one'
                                                  ,'stories_three'])
data_input
# Out:
# Enter Lot size:4200
# Enter Bathrooms:1
# Enter Drive way:0
# Enter Fullbase:1
# Enter gas hot water:0
# Enter Air condition:1
# Enter garage place:0
# Enter prefarea:1
# Enter story four:0
# Enter story one:1
# Enter story three:0
#    lotsize  bathrms  driveway  ...  stories_four  stories_one  stories_three
# 0     4200        1         0  ...             0            1              0
#
# [1 rows x 11 columns]

# %%
predict_price = lm.predict(data_input)
print('Predicted Price of House is:',predict_price[0])
# Out:
# Predicted Price of House is: 59561.00413864827

# %%
#accuracy

y_pred_price = lm.predict(x_train)
y_pred_price
# Out:
# 273     69699.608180
# 40      53062.296687
# 397     96389.432543
# 339     46458.295694
# 411    109603.681749
# 535     99730.415673
# 414     65660.648448
# 142     83674.611238
# 29      61223.702852
# 501    104414.725226
# 16      36188.790920
# 85      60780.650934
# 523     96245.314432
# 312     62704.998770
# 364    107515.467936
# 244     53919.254785
# 258     41249.854798
# 349     55072.509750
# 102     78600.550221
# 439     87057.897779
# 162     26368.546783
# 520    111007.448565
# 128     92266.647066
# 285     48510.897011
# 224     60715.701702
# 110     34618.196739
# 328    112534.202652
# 516     99094.634960
# 292     43191.757475
# 304     72824.902044
#            ...
# 431     67665.698833
# 264     45366.526693
# 209     57896.333343
# 316     64699.867730
# 513     57880.305549
# 313     75031.791901
# 319     76544.272580
# 7       60103.036253
# 393    106217.869823
# 141     53008.439172
# 86      65094.781366
# 478     95926.237790
# ...

# %%
from sklearn.metrics import r2_score

print("Model accuracy:",r2_score(y_train,y_pred_price))
# Out:
# Model accuracy: 0.6669710966728543
